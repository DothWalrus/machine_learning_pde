# %%
# Imports
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt

# Load training data
x_train = -50 + np.random.random((25000,1))*100
y = np.sin(x_train) #+ np.random.normal((25000))*.1
# Define model
model = Sequential()
model.add(Dense(100, input_dim=1, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train, y, epochs=20, batch_size=50)
# Out:
# Epoch 1/20
# 500/500 [==============================] - 2s 2ms/step - loss: 0.5730
# Epoch 2/20
# 500/500 [==============================] - 1s 2ms/step - loss: 0.4819
# Epoch 3/20
# 500/500 [==============================] - 1s 2ms/step - loss: 0.4531
# Epoch 4/20
# 500/500 [==============================] - 1s 2ms/step - loss: 0.4403
# Epoch 5/20
# 500/500 [==============================] - 1s 2ms/step - loss: 0.4202
# Epoch 6/20
# 500/500 [==============================] - 1s 1ms/step - loss: 0.4110
# Epoch 7/20
# 500/500 [==============================] - 1s 1ms/step - loss: 0.4053
# Epoch 8/20
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3920
# Epoch 9/20
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3778
# Epoch 10/20
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3700
# Epoch 11/20
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3657
# Epoch 12/20
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3588
# Epoch 13/20
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3614
# Epoch 14/20
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3483
# Epoch 15/20
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3386
# Epoch 16/20
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3333
# Epoch 17/20
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3376
# Epoch 18/20
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3291
# Epoch 19/20
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3311
# Epoch 20/20
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3310

# %%
x = -50 + np.random.random((2500,1))*100
predictions = model.predict(x)
print(np.shape(y))
#plot
plt.scatter(x_train, y, s = 1, label='sin(x)')
plt.scatter(x, predictions, s=1, label='approximation')
plt.xlabel('x')
plt.title('Learn Sine')
plt.ylabel('y')
#plt.legend('')
plt.show()
# Out:
# (25000, 1)
